# %% [markdown]
# # if elif else
# ![](https://pic2.zhimg.com/80/v2-c066de25f747b0ce68fa5f9c0df464fd_1440w.webp  )
# 縮排
# 判斷式
# 流程控制
# 巢狀判斷式

# %%
# score 90 A  80 B 70 C 60 D >60 F
score=int(input("input score:"))
grade=""
if score>=90:
  pass
elif False:
  pass
elif False:
  pass
elif False:
  pass
elif False:
  pass
print("%d %s" %(score,grade))
# Out:
# input score:6
# 6

# %%
# score 90 A  80 B 70 C 60 D >60 F
score=int(input("input score:"))
grade=""
if score<60:
  pass
elif score<70:
  pass
elif False:
  pass
elif False:
  pass
elif False:
  pass
print("%d %s" %(score,grade))

# %%
# score 90 A  80 B 70 C 60 D >60 F
score=int(input("input score:"))
grade=""
if score<60:
  pass
elif score>=60 and score<70:
  pass
elif score>=70 and score<80:
  pass
elif False:
  pass
elif False:
  pass
print("%d %s" %(score,grade))

# %%
# 10000 或以上有打折(discount)
# 1萬-9.99萬 0.8
# 10萬-49萬 0.85
# 50萬-2萬 0.90
# 1萬-10萬 0.95

amount=int(input("input amount:"))
total=0
if amount>=10000:
  if amount<10000:
    pass
  elif False:
    pass
  elif False:
    pass
  elif False:
    pass
  elif False:
    pass
else:
  total=amount

print("%d %d" %(amount,total))
