# %% [markdown]
# # List Methods
#
#
# ![](https://media.licdn.com/dms/image/D4D22AQFCfpyVTSLPbg/feedshare-shrink_2048_1536/0/1680552071559?e=1694044800&v=beta&t=cyMxEyVfO-GwXj286PH0ztE9xOrOm31MtH2FgCtEhvQ)
# ![](https://res.cloudinary.com/dyd911kmh/image/upload/f_auto,q_auto:best/v1592084676/list3_ldpeim.png)
#
#
# index()搜尋

# %%
list1=["banana"]
list1.count("w")
# Out:
# 0

# %%
colourOfRainbow=["紅","橙","黃","綠","藍","靛","紫"]
idx=colourOfRainbow.index("黃")
idx
# Out:
# 2

# %%
idx=colourOfRainbow.index("黃藍") # ValueError: '黃藍' is not in list

# %% [markdown]
# count()計算次數

# %%
cnt=colourOfRainbow.count("黃")
cnt
# Out:
# 1

# %%
cnt=colourOfRainbow.count("黃藍")
cnt
# Out:
# 0

# %% [markdown]
# # 串列元素新增和刪除
# append(item)增加串列元素
# insert(idx,item)方法

# %%
colourOfRainbow[8]="黃藍" # IndexError: list assignment index out of range
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-676089814706> in <cell line: 1>()
# ----> 1 colourOfRainbow[8]="黃藍"
#
# IndexError: list assignment index out of range

# %%
scores=[]
scores.append(1)
scores.append(2)
scores.append(3)
scores.append(4)
scores
# Out:
# [1, 2, 3, 4]

# %%
scores.insert(3,"yellow")
scores
# Out:
# [1, 2, 3, 'yellow', 4]

# %%
scores=[]
total= inscore =0
while(inscore != -1):
  inscore=int(input("input student mark:"))
  if(inscore!=-1):
    scores.append(inscore)
print("students:",len(scores))
for mark in scores:
  total += mark
average= total /(len(scores))
print(" %d   %5.2f" % (total,average))
# Out:
# input student mark:77
# input student mark:88
# input student mark:99
# input student mark:66
# input student mark:-1
# students: 4
#  330   82.50

# %% [markdown]
# # 刪除串列元素
# remove(item)
# pop()或pop(idx)方法
# del lista(idx)
# del lista(idx1:idx2:n3) # start end sep

# %%
fourSeason=["spring","summer","fall","winter"]
fourSeason.remove("fall")
fourSeason.insert(2,"autumn")
" ".join(fourSeason)
# Out:
# 'spring summer autumn winter'

# %%
fourSeason.pop()
# Out:
# 'winter'

# %%
fourSeason.insert(3,"winter")
while fourSeason.count("winter")>1:
  fourSeason.remove("winter")
fourSeason
# Out:
# ['spring', 'summer', 'autumn', 'winter']

# %%
fourSeason=["spring","summer","fall","winter"]
fourSeason.pop(2)
# Out:
# 'fall'

# %%
fourSeason
# Out:
# ['spring', 'summer', 'winter']

# %% [markdown]
# # dell
# dell list[idx]
# dell list[::]

# %%
fourSeason=["spring","summer","fall","winter"]
del fourSeason[2]
fourSeason
# Out:
# ['spring', 'summer', 'winter']

# %%
fourSeas=["spring","summer","fall","winter"]
twoSeas=fourSeas[0:3:2]
print(twoSeas)
print(fourSeas)
del fourSeas[0:3:2]
print(fourSeas)
# Out:
# ['spring', 'fall']
# ['spring', 'summer', 'fall', 'winter']
# ['summer', 'winter']

# %% [markdown]
# sort()由小到大排序
# reverse()反轉排序

# %%
list1=[3,2,1,3,4,5,7]
list1.sort()
list1
# Out:
# [1, 2, 3, 3, 4, 5, 7]

# %%
list1=[3,2,1,3,4,5,7]

# %%
print(list1)
list1.sort()
list1.reverse()
list1
# Out:
# [3, 2, 1, 3, 4, 5, 7]
# [7, 5, 4, 3, 3, 2, 1]

# %% [markdown]
# sorted(list1,reverse=True)排序產生新的串列不改變本身串列
# 克龍clone串列
# list2=sorted(list1,reverse=True)

# %%
# sorted(list1,reverse=True)
# 排序產生新的串列不改變本身串列,克龍clone串列
list1=[3,2,1,3,4,5,7]
list2=sorted(list1,reverse=True)
list2
# Out:
# [7, 5, 4, 3, 3, 2, 1]

# %%
list1
# Out:
# [3, 2, 1, 3, 4, 5, 7]

# %% [markdown]
# 元組Tuple
# tup=(1,2,3,4)
# 不可修改的串列。

# %%
tup=(1,2,3,4)
print(tup[0])
print(len(tup))
print(len(tup[::-1]))
print(len(tup[::2]))

tup[0]=7 # Error
tup.append(10) #Error
# Out:
# 1
# 4
# 4
# 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-5e3df3a9b03d> in <cell line: 7>()
#       5 print(len(tup[::2]))
#       6
# ----> 7 tup[0]=7 # Error
#       8 tup.append(10) #Error
#       9
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # list 和 tuple 轉換

# %%
tup=(1,2,3,4)
list1=list(tup)
list1.append(5)
tup=tuple(list1)
tup
# Out:
# (1, 2, 3, 4, 5)

# %%
list1=[1,2,3,4,5,6]
list1.insert(5,"love")
list1.insert(101010010,"mo")
list1
# Out:
# [1, 2, 3, 4, 5, 'love', 6, 'mo']
