# %% [markdown]
# ## 字典進階操作
# len(dict1)
# dict1.copy() -> dict2
# key in dict1
# dict1.items()
# dict1.setdefault(key,val)
# dict1.values()

# %% [markdown]
# ### in

# %%
# in
# "gs" in dict1 ?
dict1={"chn":90,"eng":80,"mat":87}
print("gs" in dict1)        #True or False
# Out:
# False

# %% [markdown]
# ### Keys Values

# %%
dict1.keys()
# Out:
# dict_keys(['chn', 'eng', 'mat'])

# %%
dict1.values()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-52a3dcf36ebc> in <cell line: 1>()
# ----> 1 dict1.values()
#
# NameError: name 'dict1' is not defined

# %% [markdown]
# ### items

# %%
dict1.items()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-5bbf025edbff> in <cell line: 1>()
# ----> 1 dict1.items()
#
# NameError: name 'dict1' is not defined

# %%
items=dict1.items()
for ite in items:
  print(ite)
# Out:
# ('chn', 90)
# ('eng', 80)
# ('mat', 87)

# %% [markdown]
# ### setdefault

# %%
dict1.setdefault("chn",70)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-374a37fd3925> in <cell line: 1>()
# ----> 1 dict1.setdefault("chn",70)
#
# NameError: name 'dict1' is not defined

# %%
dict10={}
bala=dict10.setdefault("bala")
dict10
# Out:
# {'bala': None}

# %%
bala==None
# Out:
# True

# %%
gs_score=dict1.setdefault("gs",70)
gs_score
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-2565185d09e7> in <cell line: 1>()
# ----> 1 gs_score=dict1.setdefault("gs",70)
#       2 gs_score
#
# NameError: name 'dict1' is not defined

# %% [markdown]
# ### pm2.5
# |地區 |指數 |
# |--|--|
# |zh| 6|
# |zs| 2|
# |mo| 5|
# |tc| 8|

# %%
#  pm2.5
pm25={}
area=input("input area:")
area_pm25=0





print(" %s region 's pm2.5 is %5.2f" % (area,area_pm25))
# Out:
# input area:mo
#  mo region 's pm2.5 is  0.00

# %%
text="""
please input the correct place name
This place can search:
MacauTaipa
Macau
Zhuhai
Zhongshan
"""
print(text)
while True:
  pm25={"Zhuhai":6,"Zhongshan":2,"Macau":5,"MacauTaipa":8}
  area_qus=str(input("What Places Do you live? (Ask number ofPM2.5)"))
  if area_qus in pm25:
    print(area_qus,"PM2.5 is ",pm25[area_qus])
  elif area_qus=="q" or area_qus=="Q" :
    break
  else:
    print(text)
# Out:
# please input the correct place name
# This place can search:
# MacauTaipa
# Macau
# Zhuhai
# Zhongshan
#
# What Places Do you live? (Ask number ofPM2.5)Macau
# Macau PM2.5 is  5
# What Places Do you live? (Ask number ofPM2.5)MacauTaipa
# MacauTaipa PM2.5 is  8
# What Places Do you live? (Ask number ofPM2.5)Zhuhai
# Zhuhai PM2.5 is  6
# What Places Do you live? (Ask number ofPM2.5)Zhongshan
# Zhongshan PM2.5 is  2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-7a82636badd2> in <cell line: 10>()
#      10 while True:
#      11   pm25={"Zhuhai":6,"Zhongshan":2,"Macau":5,"MacauTaipa":8}
# ---> 12   area_qus=str(input("What Places Do you live? (Ask number ofPM2.5)"))
#      13   if area_qus in pm25:
#      14     print(area_qus,"PM2.5 is ",pm25[area_qus])
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
# ...
